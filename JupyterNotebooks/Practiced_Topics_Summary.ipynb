# %% [markdown]
# # Practiced Topics Summary
# This notebook summarizes the main topics practiced in the course Jupyter notebooks. Each section highlights the key concepts and skills covered.

# %% [markdown]
# ## How to use this summary
# - Each section maps to one or more notebooks in the `JupyterNotebooks/` folder.
# - Use this as a quick revision sheet or to find which notebook to open for examples.

# %% [markdown]
# ## 1. Introduction to Python and AI
# - Overview of Python as a programming language for AI
# - Applications of AI in real-world scenarios
# - Setting up the Python environment and basic syntax
# - Notebook references: `Chapter 1 - Introduction to Python and AI.ipynb`, `Practice - Introduction to Python and AI.ipynb`

# %% [markdown]
# ## 2. Python Basics: Data Types, Operators, and Control Structures
# - Variables and basic data types (int, float, str, bool)
# - Input/output functions
# - Operators (arithmetic, comparison, logical)
# - Control structures: if, elif, else
# - Loops: for and while
# - Notebook references: `Chapter 2 - Python Basics - Data Types, Operators, and Control Structures/`

# %% [markdown]
# ## 3. Functions, Scope, and Recursion
# - Defining and calling functions
# - Parameters, arguments, and return values
# - Variable scope: local vs global
# - Recursion basics and AI use cases (tree traversals)
# - Lambda functions for concise code
# - Notebook references: `Chapter 3 - Functions, Scope, and Recursion/`

# %% [markdown]
# ## 4. Data Structures & File Handling (Overview)
# - Core data structures: lists, tuples, sets, dictionaries
# - File I/O, exceptions, and modules
# - Notebook references: `Chapter 4 - Data Structures in Python/`, `Chapter 5 - File Handling, Exceptions, and Modules/`

# %% [markdown]
# ## 5. Object-Oriented Programming (OOP)
# - Classes, objects, methods, and inheritance
# - Encapsulation and basic design patterns
# - Notebook references: `Chapter 6 - Object-Oriented Programming in Python/`

# %% [markdown]
# ## 6. Data Manipulation with NumPy and Pandas
# - Array operations, indexing, broadcasting (NumPy)
# - DataFrames, selection, grouping, merging (Pandas)
# - Notebook references: `Chapter 7 - Data Manipulation with NumPy and Pandas/`

# %% [markdown]
# ## 13. Final Project and Deployment Basics
# - Project structure, packaging, simple deployment ideas (Flask, Streamlit)
# - Notebook references: `Chapter 14 - Final Project and Deployment Basics/`

# %% [markdown]
# ## 12. Natural Language Processing (NLP) Basics
# - Tokenization, embeddings, simple text classification workflows
# - Notebook references: `Chapter 13 - Natural Language Processing Basics/`

# %% [markdown]
# ## 11. Introduction to Deep Learning
# - Neural network basics, Keras/TensorFlow examples
# - Notebook references: `Chapter 12 - Introduction to Deep Learning/`

# %% [markdown]
# ## 10. Unsupervised Learning
# - Clustering (k-means), dimensionality reduction (PCA)
# - Notebook references: `Chapter 11 - Unsupervised Learning/`

# %% [markdown]
# ## 9. Supervised Learning: Regression and Classification
# - Linear Regression (fitting, prediction, MSE)
# - Classification algorithms: Logistic Regression, Decision Trees, Random Forests, SVM
# - Notebook references: `Chapter 10 - Supervised Learning - Regression and Classification/`

# %% [markdown]
# ## 8. Introduction to Machine Learning
# - Supervised vs unsupervised learning
# - Basic pipelines: data split, training, evaluation
# - Notebook references: `Chapter 9 - Introduction to Machine Learning/`

# %% [markdown]
# ## 7. Data Visualization with Matplotlib and Seaborn
# - Creating plots: line, scatter, bar, histograms
# - Styling and subplots, Seaborn higher-level APIs
# - Notebook references: `Chapter 8 - Data Visualization with Matplotlib and Seaborn/`
